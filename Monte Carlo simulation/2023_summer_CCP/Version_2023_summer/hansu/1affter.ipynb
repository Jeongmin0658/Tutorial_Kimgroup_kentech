# %% [markdown]
# # Part I. Plotting data

# %% [markdown]
# # 1 - Below is an example to plot y=x^2.

# %%
# import necessary libraries

#한수
import matplotlib.pyplot as plt
import numpy as np
import math
# Create an array of x values from -10 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
y = np.linspace(3, 3,100)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = x^3$')

# Display the plot
plt.show()

# %% [markdown]
# # 3 - You have more pratice examples.
#
# (a) $y=x^2+4x–5$ (-5<x<10)
#
#     (Optional) Plot the solutions of this quadatic equation as points.

# %% [markdown]
# # 2 - Now you choose your favorite function to plot!

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# Create an array of x values from -10 to 10
x = np.linspace(-5, 10, 100)

# Compute the corresponding y values
y = x**2+4*x-5

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)
ax.plot(-5,0,"o")
ax.plot(1,0,"o")

# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = x^2+4x-5$')

# Display the plot
plt.show()

# %% [markdown]
# (b) $y=7*\cos(\pi x)$ (0<x<10)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# Create an array of x values from -10 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
y = 7*np.cos(np.pi*x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = 7cos(pix)$')

# Display the plot
plt.show()

# %% [markdown]
# (d) $y=-\log_{10}(x)$
#
#     (d-i)(0<x<100)
#
#     (d-ii)(0<x<1000 and set x axis to logscale)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.logspace(0.1, 100, 100)

# Compute the corresponding y values
y = -np.log10(x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes

ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = -log_{10}x$')

# Display the plot
plt.show()

# Create an array of x values from -10 to 10
x = np.logspace(0.1, 100, 100)

# Compute the corresponding y values
y = -np.log10(x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()


plt.xscale('log')
# Plot the data
ax.plot(x, y)

# Add labels for x and y axes

ax.set_xlabel('x (log)')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = -log_{10}x$')

# Display the plot
plt.show()

# %% [markdown]
# (e) $y = \exp(-x/t)$ with $t$ = 1,10,100
#
#     (e-i) Linear x axis, Linear y axis
#
#     (e-ii) Log x axis, Linear y axis

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# Create an array of x values from -10 to 10
x = np.linspace(-1, 1, 100)
t= ["t= 1", "t= 10","t= 100"]
# Compute the corresponding y values
y = np.exp(-x)
y1 = np.exp(-x/10)
y2 = np.exp(-x/100)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)
ax.plot(x, y1)
ax.plot(x, y2)
# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')
# Add a title
ax.set_title('$y = e^{-x/t}$')
# Display the plot
plt.legend(t)
# Create an array of x values from -10 to 10
# Display the plot
plt.show()

x = np.linspace(-1, 1, 100)
t= ["t= 1", "t= 10","t= 100"]
# Compute the corresponding y values
y = np.exp(-x)
y1 = np.exp(-x/10)
y2 = np.exp(-x/100)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)
ax.plot(x, y1)
ax.plot(x, y2)
# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y logscale')
# Add a title
ax.set_title('$y = exp(-x/t)$')
plt.yscale('log')
# Display the plot
plt.legend(t)
# Create an array of x values from -10 to 10
# Display the plot
plt.show()

# %% [markdown]
# (f) $y = \exp(-x^2/D)$ with $D$ = 1,5,10 ( -10 < x < 10 )
#
#     (Optional) Think about how to present data effectively

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# Create an array of x values from -10 to 10
x = np.linspace(-10, 10, 100)
k = x ** 2
# Compute the corresponding y values
y = np.exp(-k)
y1 = np.exp(-k/5)
y2 =np.exp(-k/10)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()
D = ["D = 1","D =5", "D =10"]
# Plot the data
ax.plot(x, y)
ax.plot(x, y1)
ax.plot(x, y2)
# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y aixs')

# Add a title
ax.set_title('$y = e^{-x^2/D}$')
plt.legend(D)
# Display the plot
plt.show()
# Create an array of x values from -10 to 10

x = np.linspace(-10, 10, 100)
k = x ** 2
# Compute the corresponding y values
y = np.exp(-k)
y1 = np.exp(-k/5)
y2 =np.exp(-k/10)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()
D = ["D = 1","D =5", "D =10"]
# Plot the data
ax.plot(x, y)
ax.plot(x, y1)
ax.plot(x, y2)
# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y logscale')
plt.yscale('log')
# Add a title
ax.set_title('$y = exp(-x^2/D)$')
plt.legend(D)
# Display the plot
plt.show()

# %%
x = np.linspace(-10, 10, 100)
k = x ** 2
# Compute the corresponding y values

def dg(x, k):
  y = np.exp(- x*x/k)
  return y

y = np.exp(-k)
y1 = np.exp(-k/5)
y2 =np.exp(-k/10)
x1 = np.linspace(-10, 10, 10)
z1 = dg(x1,1)
z2 = dg(x1,5)
z3 = dg(x1, 10)
fig, ax = plt.subplots()
ax.scatter(x1, z1)
ax.scatter(x1, z2)
ax.scatter(x1, z3)
# Create a figure and a set of subplots (this is often combined in one step)
D = ["D = 1","D =5", "D =10"]
# Plot the data
ax.plot(x, y)
ax.plot(x, y1)
ax.plot(x, y2)
# Add labels for x and y axes
ax.set_xlabel('x aixs')
ax.set_ylabel('y logscale')
plt.yscale('log')
# Add a title

ax.set_title('$y = exp(-x^2/D)$')
plt.legend(D)
# Display the plot
plt.show()
