# %% [markdown]
# # Part I. Plotting data

# %% [markdown]
# # 1 - Below is an example to plot y=x^2.

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(-10, 10, 100)

# Compute the corresponding y values
y = x ** 2

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y = x^2$')

# Display the plot
plt.show()

# %% [markdown]
# # 2 - Now you choose your favorite function to plot!

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
y = x ** 0.5

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y = x^2$')

# Display the plot
plt.show()

# %% [markdown]
# # 3 - You have more pratice examples.
#
# (a) $y=x^2+4x–5$ (-5<x<10)
#
#     (Optional) Plot the solutions of this quadatic equation as points.

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(-5, 10, 100)

# Compute the corresponding y values
y = x ** 2 + 4*x - 5

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y = x^2 + 4x - 5$')

# Display the plot
plt.show()

# %% [markdown]
# (b) $y=7*\cos(\pi x)$ (0<x<10)
#
# (d) $y=-\log_{10}(x)$
#
#     (d-i)(0<x<100)
#
#     (d-ii)(0<x<1000 and set x axis to logscale)

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
y = 7 * np.sin(np.pi * x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y=7\cos(\pi x)$')

# Display the plot
plt.show()

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0, 100, 1000)

# Compute the corresponding y values
y = -1 * np.log10(x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y=-\log_{10}(x)$')

# Display the plot
plt.show()
# Out:
# <ipython-input-26-cdb97902cce1>:9: RuntimeWarning: divide by zero encountered in log10
#   y = -1 * np.log10(x)

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0, 1000, 1000)

# Compute the corresponding y values
y = -1 * np.log10(x)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(np.log(x), y)

# Add labels for x and y axes
ax.set_xlabel('x (ln scale)')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y=-\log_{10}(x)$ with log scale x')

# Display the plot
plt.show()
# Out:
# <ipython-input-34-8a644ba06d28>:9: RuntimeWarning: divide by zero encountered in log10
#   y = -1 * np.log10(x)
# <ipython-input-34-8a644ba06d28>:15: RuntimeWarning: divide by zero encountered in log
#   ax.plot(np.log(x), y)

# %% [markdown]
# (e) $y = \exp(-x/t)$ with $t$ = 1,10,100
#
#     (e-i) Linear x axis, Linear y axis
#
#     (e-ii) Log x axis, Linear y axis

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(-100, 100, 100)

# Compute the corresponding y values
y = np.exp(-x/t)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x,y)

# Add labels for x and y axes
ax.set_xlabel('x (ln scale)')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y=-\log_{10}(x)$ with log scale x')

# Display the plot
plt.show()

# %% [markdown]
# (f) $y = \exp(-x^2/D)$ with $D$ = 1,5,10 ( -10 < x < 10 )
#
#     (Optional) Think about how to present data effectively
