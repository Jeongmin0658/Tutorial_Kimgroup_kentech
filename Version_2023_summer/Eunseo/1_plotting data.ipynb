# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeongmin0658/kentech_tutorial/blob/main/Version_2023_summer/Eunseo/1_plotting%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part I. Plotting data

# %% [markdown]
# # 1 - Below is an example to plot y=x^2.

# %%
#upload test

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -10 to 10
x = np.linspace(-10, 10, 100)

# Compute the corresponding y values
y = x ** 2

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y = x^2$')

# Display the plot
plt.show()

# %% [markdown]
# # 2 - Now you choose your favorite function to plot!

# %%
#new

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -20 to 20
x = np.linspace(-20, 20, 1000)

# Compute the corresponding y values
y = x ** 3

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$y = x^3$')

# Display the plot
plt.show()

# %% [markdown]
# # 3 - You have more pratice examples.
#
# (a) $y=x^2+4x–5$ (-5<x<10)
#
#     (Optional) Plot the solutions of this quadatic equation as points.

# %%
# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -5 to 10
x = np.linspace(-5, 10, 100)

# Compute the corresponding y values
y = x**2 + 4*x - 5

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=𝑥^2+4𝑥–5$')

# Display the plot
plt.show()

# %% [markdown]
# (b) $y=7*\cos(\pi x)$ (0<x<10)

# %%
# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from 0 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
y=7*np.cos(np.pi*𝑥)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=7∗cos(𝜋𝑥)$')

# Display the plot
plt.show()

# %% [markdown]
# (d) $y=-\log_{10}(x)$
#
#     (d-i)(0<x<100)
#
#     (d-ii)(0<x<1000 and set x axis to logscale)

# %%
#d-i

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from 0 to 10
x = np.linspace(0, 100, 100)

# Compute the corresponding y values
𝑦=-np.log10(𝑥)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=−log10(𝑥)$')

# Display the plot
plt.show()
# Out:
# <ipython-input-18-479bcc1750ed>:9: RuntimeWarning: divide by zero encountered in log10
#   𝑦=-np.log10(𝑥)

# %%
#d-ii

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from 0 to 10
x = np.linspace(0.1, 1000, 1000)

# Compute the corresponding y values
𝑦=-np.log10(𝑥)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis(logscale)')
ax.set_ylabel('y axis')
ax.set_xscale('log')

# Add a title
ax.set_title('$𝑦=−log10(𝑥)$')

# Display the plot
plt.show()

# %% [markdown]
# (e) $y = \exp(-x/t)$ with $t$ = 1,10,100
#
#     (e-i) Linear x axis, Linear y axis
#
#     (e-ii) Log x axis, Linear y axis

# %%
#e-i
#t=1

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-100, 100, 1000)

# Compute the corresponding y values
𝑦=np.exp(-𝑥)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=exp(−𝑥)$')

# Display the plot
plt.show()

# %%
#e-i

#t=10

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-100, 100, 1000)

# Compute the corresponding y values
𝑦=np.exp(-𝑥/10)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=exp(−𝑥/10)$')

# Display the plot
plt.show()

# %%
#e-i

#t=100

# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-100, 100, 1000)

# Compute the corresponding y values
𝑦=np.exp(-𝑥/100)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$𝑦=exp(−𝑥/100)$')

# Display the plot
plt.show()

# %%
#e-ii
#t=1
# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-10, 10, 100)

# Compute the corresponding y values
𝑦=np.exp(-𝑥)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis(log scale)')
ax.set_ylabel('y axis')
ax.set_xscale('log')

# Add a title
ax.set_title('$𝑦=exp(−𝑥)$')

# Display the plot
plt.show()

# %%
#e-ii
#t=10
# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-10, 10, 100)

# Compute the corresponding y values
𝑦=np.exp(-𝑥/10)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_xscale('log')

# Add a title
ax.set_title('$𝑦=exp(−𝑥/10)$')

# Display the plot
plt.show()

# %%
#e-ii
#t=100
# import necessary libraries
import matplotlib.pyplot as plt #plot
import numpy as np #number

# Create an array of x values from -100 to 100
x = np.linspace(-100, 100, 1000)

# Compute the corresponding y values
𝑦=np.exp(-𝑥/100)

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_xscale('log')

# Add a title
ax.set_title('$𝑦=exp(−𝑥/100)$')

# Display the plot
plt.show()

# %% [markdown]
# (f) $y = \exp(-x^2/D)$ with $D$ = 1,5,10 ( -10 < x < 10 )
#
#     (Optional) Think about how to present data effectively

# %%
import matplotlib.pyplot as plt

sub_plots = plt.subplots(3, 3)

fig = sub_plots[0]
graph = sub_plots[1]


x = np.linspace(-10, 10, 100)

y1=np.exp(-x**2/1)
y2=np.exp(-x**2/5)
y3=np.exp(-x**2/10)


graph[0][0].plot(x,y1)
graph[0][0].set_title('plot 1')
graph[0][0].set_xlabel('x')
graph[0][0].set_ylabel('y')

graph[0][1].plot(x,y1)
graph[0][1].set_title('plot 2')
graph[0][1].set_xlabel('x')
graph[0][1].set_ylabel('y')

graph[0][2].plot(x,y1)
graph[0][2].set_title('plot 3')
graph[0][2].set_xlabel('x')
graph[0][2].set_ylabel('y')


graph[1][0].plot(x,y2)
graph[1][0].set_title('plot 4')
graph[1][0].set_xlabel('x')
graph[1][0].set_ylabel('y')


graph[1][1].plot(x,y2)
graph[1][1].set_title('plot 5')
graph[1][1].set_xlabel('x')
graph[1][1].set_ylabel('y')

graph[1][2].plot(x,y2)
graph[1][2].set_title('plot 6')
graph[1][2].set_xlabel('x')
graph[1][2].set_ylabel('y')

graph[2][0].plot(x,y2)
graph[2][0].set_title('plot 7')
graph[2][0].set_xlabel('x')
graph[2][0].set_ylabel('y')

graph[2][1].plot(x,y2)
graph[2][1].set_title('plot 8')
graph[2][1].set_xlabel('x')
graph[2][1].set_ylabel('y')

graph[2][2].plot(x,y2)
graph[2][2].set_title('plot 9')
graph[2][2].set_xlabel('x')
graph[2][2].set_ylabel('y')

fig.suptitle('Multiple plots')
fig.tight_layout(pad=2)
plt.show()
