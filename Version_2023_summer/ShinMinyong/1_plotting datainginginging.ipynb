# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeongmin0658/kentech_tutorial/blob/main/Version_2023_summer/ShinMinyong/1_plotting%20datainginginging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part I. Plotting data

# %% [markdown]
# # 1 - Below is an example to plot y=x^2.

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(-10, 10, 100)

# Compute the corresponding y values
y = x ** 2

# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Add a title
ax.set_title('$y = x^2$')

# Display the plot
plt.show()

# %% [markdown]
# # 2 - Now you choose your favorite function to plot!

# %%
# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(-1000000, 1000000, 100)

# Compute the corresponding y values
# y = x ** 5+ 4*x ** 3 -2*x **2 +2
y_1 = np.exp(-x/1)
y_2 = np.exp(-x/10)
y_3 = np.exp(-x/100)
# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$y =nanananana graph')

# Display the plot
plt.show()
# Out:
# <ipython-input-19-9bb2d8bc0965>:10: RuntimeWarning: overflow encountered in exp
#   y_1 = np.exp(-x/1)
# <ipython-input-19-9bb2d8bc0965>:11: RuntimeWarning: overflow encountered in exp
#   y_2 = np.exp(-x/10)
# <ipython-input-19-9bb2d8bc0965>:12: RuntimeWarning: overflow encountered in exp
#   y_3 = np.exp(-x/100)

# %% [markdown]
# # 3 - You have more pratice examples.
#
# (a) $y=x^2+4x–5$ (-5<x<10)
#
#     (Optional) Plot the solutions of this quadatic equation as points.
#
# (b) $y=7*\cos(\pi x)$ (0<x<10)
#
# (d) $y=-\log_{10}(x)$
#
#     (d-i)(0<x<100)
#
#     (d-ii)(0<x<1000 and set x axis to logscale)
#
# (e) $y = \exp(-x/t)$ with $t$ = 1,10,100
#
#     (e-i) Linear x axis, Linear y axis
#
#     (e-ii) Log x axis, Linear y axis
#
# (f) $y = \exp(-x^2/D)$ with $D$ = 1,5,10 ( -10 < x < 10 )
#
#     (Optional) Think about how to present data effectively

# %%
# import necessary libraries
#예제d2
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0.001, 1000, 100)

# Compute the corresponding y values
# y = x ** 5+ 4*x ** 3 -2*x **2 +2
y = -np.log10(x)
# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(np.log10(x), y)

# Add labels for x and y axes
ax.set_xlabel('log10(x) axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$y =-log10(x) graph')

# Display the plot
plt.show()

# %%
# import necessary libraries
#예제d1
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0.001, 100, 100)

# Compute the corresponding y values
# y = x ** 5+ 4*x ** 3 -2*x **2 +2
y = -np.log10(x)
# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$y =-log10(x) graph')

# Display the plot
plt.show()

# %%
# import necessary libraries
#예제b
import matplotlib.pyplot as plt
import numpy as np

# Create an array of x values from -10 to 10
x = np.linspace(0, 10, 100)

# Compute the corresponding y values
# y = x ** 5+ 4*x ** 3 -2*x **2 +2
y = 7*np.cos(np.pi*x)
# Create a figure and a set of subplots (this is often combined in one step)
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Add labels for x and y axes
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# Add a title
ax.set_title('$y = x^5$ graph')

# Display the plot
plt.show()
